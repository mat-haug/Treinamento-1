# %%
import pandas as pd

base_artistas = pd.read_csv("spotify_artists.csv")

base_artistas.head()
# Out:
#    Unnamed: 0  artist_popularity  followers  \
# 0           0                 44      23230
# 1           1                 22        313
# 2           2                 26       1596
# 3           3                 31        149
# 4           4                 21         11
#
#                                               genres                      id  \
# 0  ['sertanejo', 'sertanejo pop', 'sertanejo trad...  4mGnpjhqgx4RUdsIJiURdo
# 1                                                 []  1dLnVku4VQUOLswwDFvRc9
# 2                                ['danish pop rock']  6YVY310fjfUzKi8hiqR7iK
# 3                             ['uk alternative pop']  2VElyouiCfoYPDJluzwJwK
# 4                                 ['french baroque']  4agVy03qW8juSysCTUOuDI
#
#                   name                track_id track_name_prev    type
# 0        Juliano Cezar  0wmDmAILuW9e2aRttkl4aC         track_9  artist
# 1       The Grenadines  4wqwj0gA8qPZKLl5WVqXml        track_30  artist
# ...

# %%
base_artistas.describe()
# Out:
#          Unnamed: 0  artist_popularity     followers
# count  56129.000000       56129.000000  5.612900e+04
# mean   28064.000000          34.387447  7.796041e+04
# std    16203.190967          16.917287  5.942273e+05
# min        0.000000           0.000000  0.000000e+00
# 25%    14032.000000          22.000000  1.820000e+02
# 50%    28064.000000          34.000000  1.734000e+03
# 75%    42096.000000          46.000000  1.520300e+04
# max    56128.000000         100.000000  4.156169e+07

# %%
base_artistas.loc[base_artistas['followers'] == 0]
# Out:
#        Unnamed: 0  artist_popularity  followers genres  \
# 25             25                 21          0     []
# 53             53                  2          0     []
# 107           107                 20          0     []
# 115           115                 22          0     []
# 127           127                 26          0     []
# ...           ...                ...        ...    ...
# 55008       55008                 14          0     []
# 55068       55068                  0          0     []
# 55772       55772                 24          0     []
# 55805       55805                 14          0     []
# 56041       56041                  1          0     []
#
#                            id                  name                track_id  \
# 25     6CJCoqivxcdr8zlVeSsoH8          Reiko Tsuiki  7Bdop7N4EKLMk4riEXQMix
# 53     7uLlA3ipeSM7lUSmrh455d                  BiGz  0ebArfrdaqfhwOmBPe2oMt
# ...

# %%
base_artistas.isnull().sum()
base_artistas[base_artistas.isnull().any(axis=1)]
# Out:
#       Unnamed: 0  artist_popularity  followers genres                      id  \
# 3836        3836                 50       1142     []  4oPYazJJ1o4rWBrTw9lm40
#
#      name                track_id track_name_prev    type
# 3836  NaN  5OJZjoVoyNbzD24C7tkycW         track_7  artist

# %%
base_artistas.dropna(inplace = True)
base_artistas.isnull().sum()
# Out:
# Unnamed: 0           0
# artist_popularity    0
# followers            0
# genres               0
# id                   0
# name                 0
# track_id             0
# track_name_prev      0
# type                 0
# dtype: int64

# %%
artistas_deletados = base_artistas[base_artistas.followers == 0].index
base_artistas.drop(artistas_deletados, inplace=True)

# %%
base_artistas.loc[base_artistas['followers'] == 0]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, artist_popularity, followers, genres, id, name, track_id, track_name_prev, type]
# Index: []

# %%
base_artistas.nunique()
# Out:
# Unnamed: 0           55535
# artist_popularity       99
# followers            22734
# genres               13314
# id                   55535
# name                 54933
# track_id             44790
# track_name_prev        325
# type                     1
# dtype: int64

# %%
base_artistas.drop_duplicates(inplace = True)
base_artistas
# Out:
#        Unnamed: 0  artist_popularity  followers  \
# 0               0                 44      23230
# 1               1                 22        313
# 2               2                 26       1596
# 3               3                 31        149
# 4               4                 21         11
# ...           ...                ...        ...
# 56124       56124                 23       1212
# 56125       56125                 42      57973
# 56126       56126                 38      20870
# 56127       56127                 44      33923
# 56128       56128                 44      42026
#
#                                                   genres  \
# 0      ['sertanejo', 'sertanejo pop', 'sertanejo trad...
# 1                                                     []
# 2                                    ['danish pop rock']
# 3                                 ['uk alternative pop']
# 4                                     ['french baroque']
# ...

# %%
base_artistas.nunique()
# Out:
# Unnamed: 0           55535
# artist_popularity       99
# followers            22734
# genres               13314
# id                   55535
# name                 54933
# track_id             44790
# track_name_prev        325
# type                     1
# dtype: int64

# %%
base_albums = pd.read_csv("spotify_albums.csv")

base_albums.head()
# Out:
#    Unnamed: 0 album_type               artist_id  \
# 0           0     single  3DiDSECUqqY1AuBP8qtaIa
# 1           1      album  6s1pCNXcbdtQJlsnM1hRIA
# 2           2     single  5YjfNaHq05WrwldRe1QSBc
# 3           3     single  2G9Vc16JCpnZmK4uGH46Fa
# 4           4     single  2dwM9OcE4c3Ph1UBINSodx
#
#                                    available_markets  \
# 0  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 1  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 2  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 3  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 4  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/album/1g...
# 1  {'spotify': 'https://open.spotify.com/album/4K...
# 2  {'spotify': 'https://open.spotify.com/album/7n...
# 3  {'spotify': 'https://open.spotify.com/album/6p...
# 4  {'spotify': 'https://open.spotify.com/album/1X...
#
# ...

# %% [markdown]
# MERGE

# %%
import pandas as pd

df_albums = pd.read_csv(r"C:\Users\Jorge Enrico\Downloads\PJ_T1\spotify_albums.csv")
df_artists = pd.read_csv(r"C:\Users\Jorge Enrico\Downloads\PJ_T1\spotify_artists.csv")

# %%
print("Colunas de df_albums:")
print(df_albums.columns)

print("\nColunas de df_artists:")
print(df_artists.columns)
# Out:
# Colunas de df_albums:
# Index(['Unnamed: 0', 'album_type', 'artist_id', 'available_markets',
#        'external_urls', 'href', 'id', 'images', 'name', 'release_date',
#        'release_date_precision', 'total_tracks', 'track_id', 'track_name_prev',
#        'uri', 'type'],
#       dtype='object')
#
# Colunas de df_artists:
# Index(['Unnamed: 0', 'artist_popularity', 'followers', 'genres', 'id', 'name',
#        'track_id', 'track_name_prev', 'type'],
#       dtype='object')

# %%
df_albums.drop(columns=['Unnamed: 0'], inplace=True)
df_artists.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df_albums.rename(columns={'name': 'album_name'}, inplace=True)

df_artists.rename(columns={
    'id': 'artist_id',
    'name': 'artist_name'
}, inplace=True)

# %%
print(df_albums.isnull().sum())
print(df_artists.isnull().sum())
# Out:
# album_type                0
# artist_id                 0
# available_markets         0
# external_urls             0
# href                      0
# id                        0
# images                    0
# album_name                0
# release_date              0
# release_date_precision    0
# total_tracks              0
# track_id                  0
# track_name_prev           0
# uri                       0
# type                      0
# dtype: int64
# artist_popularity    0
# followers            0
# genres               0
# artist_id            0
# artist_name          1
# track_id             0
# track_name_prev      0
# type                 0
# dtype: int64

# %%
df_albums.drop_duplicates(inplace=True)
df_artists.drop_duplicates(inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_merged = pd.merge(
    left=df_albums,
    right=df_artists,
    on='artist_id',
    how='left'
)

print(df_merged.head())
print(df_merged.columns)
# Out:
#   album_type               artist_id  \
# 0     single  3DiDSECUqqY1AuBP8qtaIa
# 1      album  6s1pCNXcbdtQJlsnM1hRIA
# 2     single  5YjfNaHq05WrwldRe1QSBc
# 3     single  2G9Vc16JCpnZmK4uGH46Fa
# 4     single  2dwM9OcE4c3Ph1UBINSodx
#
#                                    available_markets  \
# 0  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 1  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 2  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 3  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 4  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/album/1g...
# 1  {'spotify': 'https://open.spotify.com/album/4K...
# 2  {'spotify': 'https://open.spotify.com/album/7n...
# 3  {'spotify': 'https://open.spotify.com/album/6p...
# 4  {'spotify': 'https://open.spotify.com/album/1X...
#
#                                                 href                      id  \
# ...

# %%
df_merged = pd.merge(
    df_albums, 
    df_artists, 
    on='artist_id', 
    how='left',
    suffixes=('_albums', '_artists')
)

# %%
print(df_albums.columns)
print(df_artists.columns)
# Out:
# Index(['album_type', 'artist_id', 'available_markets', 'external_urls', 'href',
#        'id', 'images', 'album_name', 'release_date', 'release_date_precision',
#        'total_tracks', 'track_id', 'track_name_prev', 'uri', 'type'],
#       dtype='object')
# Index(['artist_popularity', 'followers', 'genres', 'artist_id', 'artist_name',
#        'track_id', 'track_name_prev', 'type'],
#       dtype='object')

# %%
df_albums.rename(columns={'track_id': 'track_id_alb'}, inplace=True)

# %%
df_merged = pd.merge(
    df_albums,
    df_artists,
    left_on='artist_id',
    right_on='artist_id',
    how='left',
    suffixes=('_alb', '_art')
)

# %%
df_merged.head()
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75511 entries, 0 to 75510
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   album_type              75511 non-null  object
#  1   artist_id               75511 non-null  object
#  2   available_markets       75511 non-null  object
#  3   external_urls           75511 non-null  object
#  4   href                    75511 non-null  object
#  5   id                      75511 non-null  object
#  6   images                  75511 non-null  object
#  7   album_name              75511 non-null  object
#  8   release_date            75511 non-null  object
#  9   release_date_precision  75511 non-null  object
#  10  total_tracks            75511 non-null  int64
#  11  track_id_alb            75511 non-null  object
#  12  track_name_prev_alb     75511 non-null  object
#  13  uri                     75511 non-null  object
# ...

# %%
df_tracks = pd.read_csv("spotify_tracks.csv")

# %%
print("df_albums columns:", df_albums.columns)
print("df_artists columns:", df_artists.columns)
print("df_tracks columns:", df_tracks.columns)
# Out:
# df_albums columns: Index(['album_type', 'artist_id', 'available_markets', 'external_urls', 'href',
#        'id', 'images', 'album_name', 'release_date', 'release_date_precision',
#        'total_tracks', 'track_id_alb', 'track_name_prev', 'uri', 'type'],
#       dtype='object')
# df_artists columns: Index(['artist_popularity', 'followers', 'genres', 'artist_id', 'artist_name',
#        'track_id', 'track_name_prev', 'type'],
#       dtype='object')
# df_tracks columns: Index(['Unnamed: 0', 'acousticness', 'album_id', 'analysis_url', 'artists_id',
#        'available_markets', 'country', 'danceability', 'disc_number',
#        'duration_ms', 'energy', 'href', 'id', 'instrumentalness', 'key',
#        'liveness', 'loudness', 'lyrics', 'mode', 'name', 'playlist',
#        'popularity', 'preview_url', 'speechiness', 'tempo', 'time_signature',
#        'track_href', 'track_name_prev', 'track_number', 'uri', 'valence',
#        'type'],
#       dtype='object')

# %%
df_tracks.rename(columns={'id': 'track_id'}, inplace=True)

# %%
df_artists.rename(columns={'id': 'artist_id'}, inplace=True)

# %%
df_albums_artists = pd.merge(
    df_albums,
    df_artists,
    on='artist_id',      
    how='left',         
    suffixes=('_alb', '_art')  
)

# %%
df_final = pd.merge(
    df_albums_artists,
    df_tracks,
    on='track_id',       
    how='left',          
    suffixes=('_prev', '_tck')  
)

# %%
df_final.info()
df_final.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75511 entries, 0 to 75510
# Data columns (total 53 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   album_type              75511 non-null  object
#  1   artist_id               75511 non-null  object
#  2   available_markets_prev  75511 non-null  object
#  3   external_urls           75511 non-null  object
#  4   href_prev               75511 non-null  object
#  5   id                      75511 non-null  object
#  6   images                  75511 non-null  object
#  7   album_name              75511 non-null  object
#  8   release_date            75511 non-null  object
#  9   release_date_precision  75511 non-null  object
#  10  total_tracks            75511 non-null  int64
#  11  track_id_alb            75511 non-null  object
#  12  track_name_prev_alb     75511 non-null  object
#  13  uri_prev                75511 non-null  object
# ...
